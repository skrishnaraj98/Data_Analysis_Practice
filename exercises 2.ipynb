# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Sales = pd.read_csv("Downloads/Sales/Sales.csv", parse_dates = ['Date'], dayfirst = True)

# %%
Sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113036 entries, 0 to 113035
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Date              113036 non-null  datetime64[ns]
#  1   Day               113036 non-null  int64
#  2   Month             113036 non-null  object
#  3   Year              113036 non-null  int64
#  4   Customer_Age      113036 non-null  int64
#  5   Age_Group         113036 non-null  object
#  6   Customer_Gender   113036 non-null  object
#  7   Country           113036 non-null  object
#  8   State             113036 non-null  object
#  9   Product_Category  113036 non-null  object
#  10  Sub_Category      113036 non-null  object
#  11  Product           113036 non-null  object
#  12  Order_Quantity    113036 non-null  int64
#  13  Unit_Cost         113036 non-null  int64
#  14  Unit_Price        113036 non-null  int64
#  15  Profit            113036 non-null  int64
# ...

# %%
Sales.loc[(Sales['Country']=='Canada') | (Sales['Country']=='France')].shape[0]
# Out:
# 25176

# %%
Sales.loc[(Sales['Country'] == 'Canada') & (Sales['Sub_Category'] == 'Bike Racks')].shape[0]
# Out:
# 104

# %%
france_states = Sales.loc[Sales['Country']=='France', 'State'].value_counts()
france_states
# Out:
# State
# Seine (Paris)        2328
# Seine Saint Denis    1684
# Nord                 1670
# Hauts de Seine       1084
# Essonne               994
# Yveline               954
# Seine et Marne        394
# Moselle               386
# Loiret                382
# Val d'Oise            264
# Garonne (Haute)       208
# Val de Marne          158
# Charente-Maritime     148
# Somme                 134
# Loir et Cher          120
# Pas de Calais          90
# Name: count, dtype: int64

# %%
france_states.plot(kind = 'bar', figsize = (10,3))
# Out:
# <Axes: xlabel='State'>

# %%
Sales['Product_Category'].value_counts()
# Out:
# Product_Category
# Accessories    70120
# Bikes          25982
# Clothing       16934
# Name: count, dtype: int64

# %%
Sales['Product_Category'].value_counts().plot(kind = 'pie', figsize = (3,3))
# Out:
# <Axes: ylabel='count'>

# %%
Sales['Product_Category'].value_counts()
# Out:
# Product_Category
# Accessories    70120
# Bikes          25982
# Clothing       16934
# Name: count, dtype: int64

# %%
Sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113036 entries, 0 to 113035
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Date              113036 non-null  datetime64[ns]
#  1   Day               113036 non-null  int64
#  2   Month             113036 non-null  object
#  3   Year              113036 non-null  int64
#  4   Customer_Age      113036 non-null  int64
#  5   Age_Group         113036 non-null  object
#  6   Customer_Gender   113036 non-null  object
#  7   Country           113036 non-null  object
#  8   State             113036 non-null  object
#  9   Product_Category  113036 non-null  object
#  10  Sub_Category      113036 non-null  object
#  11  Product           113036 non-null  object
#  12  Order_Quantity    113036 non-null  int64
#  13  Unit_Cost         113036 non-null  int64
#  14  Unit_Price        113036 non-null  int64
#  15  Profit            113036 non-null  int64
# ...

# %%
Sales.head()
# Out:
#         Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0 2013-11-26   26  November  2013            19     Youth (<25)
# 1 2015-11-26   26  November  2015            19     Youth (<25)
# 2 2014-03-23   23     March  2014            49  Adults (35-64)
# 3 2016-03-23   23     March  2016            49  Adults (35-64)
# 4 2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %%
Sales['Sub_Category'].value_counts()
# Out:
# Sub_Category
# Tires and Tubes      33870
# Bottles and Cages    15876
# Road Bikes           13430
# Helmets              12158
# Mountain Bikes        8854
# Jerseys               6010
# Caps                  4358
# Fenders               4032
# Touring Bikes         3698
# Gloves                2686
# Cleaners              1802
# Shorts                1794
# Hydration Packs       1334
# Socks                 1122
# Vests                  964
# Bike Racks             592
# Bike Stands            456
# Name: count, dtype: int64

# %%
order_per_accessory = Sales.loc[Sales['Product_Category'] == 'Accessories', 'Sub_Category'].value_counts()
order_per_accessory
# Out:
# Sub_Category
# Tires and Tubes      33870
# Bottles and Cages    15876
# Helmets              12158
# Fenders               4032
# Cleaners              1802
# Hydration Packs       1334
# Bike Racks             592
# Bike Stands            456
# Name: count, dtype: int64

# %%
order_per_accessory.plot(kind = 'bar', figsize = (10,3))
# Out:
# <Axes: xlabel='Sub_Category'>

# %%
order_per_bike = Sales.loc[Sales['Product_Category'] == 'Bikes', 'Sub_Category'].value_counts()
order_per_bike
# Out:
# Sub_Category
# Road Bikes        13430
# Mountain Bikes     8854
# Touring Bikes      3698
# Name: count, dtype: int64

# %%
order_per_bike.plot(kind = 'pie', figsize =(3,3))
# Out:
# <Axes: ylabel='count'>

# %%
Sales["Customer_Gender"].value_counts()
# Out:
# Customer_Gender
# M    58312
# F    54724
# Name: count, dtype: int64

# %%
Sales["Customer_Gender"].value_counts().plot(kind = 'bar', figsize = (5,3))
# Out:
# <Axes: xlabel='Customer_Gender'>

# %%
Sales_500 = Sales.loc[(Sales["Revenue"] > 500) & (Sales['Customer_Gender'] == "M")].value_counts()

Sales_500.shape[0]
# Out:
# 21663

# %%
Sales['Revenue'].head(5)
# Out:
# 0     950
# 1     950
# 2    2401
# 3    2088
# 4     418
# Name: Revenue, dtype: int64

# %%
Sales.sort_values(['Revenue'], ascending = False).head(5)
# Out:
#              Date  Day      Month  Year  Customer_Age       Age_Group  \
# 112073 2015-07-24   24       July  2015            52  Adults (35-64)
# 112072 2013-07-24   24       July  2013            52  Adults (35-64)
# 71129  2011-07-08    8       July  2011            22     Youth (<25)
# 70307  2011-04-30   30      April  2011            44  Adults (35-64)
# 70601  2011-09-30   30  September  2011            19     Youth (<25)
#
#        Customer_Gender    Country             State Product_Category  \
# 112073               M  Australia        Queensland         Clothing
# 112072               M  Australia        Queensland         Clothing
# 71129                M     Canada           Alberta            Bikes
# 70307                M     Canada  British Columbia            Bikes
# 70601                F     Canada  British Columbia            Bikes
#
#        Sub_Category                  Product  Order_Quantity  Unit_Cost  \
# ...

# %%
Sales.loc[Sales["Revenue"] == Sales['Revenue'].max()]
# Out:
#              Date  Day Month  Year  Customer_Age       Age_Group  \
# 112073 2015-07-24   24  July  2015            52  Adults (35-64)
#
#        Customer_Gender    Country       State Product_Category Sub_Category  \
# 112073               M  Australia  Queensland         Clothing        Vests
#
#                         Product  Order_Quantity  Unit_Cost  Unit_Price  \
# 112073  Touring-1000 Yellow, 50              29       1482        2384
#
#         Profit   Cost  Revenue
# 112073   15096  42978    58074

# %%
New_order = Sales["Revenue"] > 10000

# %%
Sales.loc[New_order, "Order_Quantity"].mean()
# Out:
# 3.7218934911242605

# %%
Sales.loc[(Sales["Year"] == 2016) & (Sales["Month"] == "May")].shape
# Out:
# (5015, 18)

# %%
cond = (Sales['Year'] == 2016) & (Sales['Month'] == 'May')

Sales.loc[cond].shape[0]
# Out:
# 5015

# %%
Sales.loc[(Sales["Year"] == 2016) & ((Sales['Month'] == "May") | (Sales["Month"] == "July") | (Sales["Month"] == "June") )].shape
# Out:
# (12164, 18)

# %%
cond = (Sales['Year'] == 2016) & (Sales['Month'].isin(['May', 'June', 'July']))

Sales.loc[cond].shape[0]
# Out:
# 12164

# %%
new_order = (Sales["Year"] == 2016) & (Sales["Month"].isin(["May", "June", "July"]))

Sales.loc[new_order].shape[0]
# Out:
# 12164

# %%
profit_2016 = Sales.loc[Sales["Year"] == 2016, ["Profit", "Month"]]
profit_2016.boxplot(by= "Month", vert = False, figsize = (10,3))
# Out:
# <Axes: title={'center': 'Profit'}, ylabel='[Month]'>

# %%
USA_sales = Sales.loc[Sales["Country"] == "United States", "Unit_Price"]

# %%
USA_sales *= (1.072)

# %%
USA_sales.head()
# Out:
# 22    128.64
# 23    128.64
# 34    128.64
# 35    128.64
# 38    128.64
# Name: Unit_Price, dtype: float64

# %%
Sales.loc[(Sales['Revenue']>10000), "Order_Quantity"].mean()
# Out:
# 3.7218934911242605
