# %%
import pandas as pd
import numpy as np

# %%
pwd
# Out:
# 'C:\\Users\\lenovo\\Pandas Folder'

# %%
cd
# Out:
# C:\Users\lenovo

# %%
pd.read_csv("Fortune 500 Companies US.csv", encoding='latin1')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 pd.read_csv("Fortune 500 Companies US.csv", encoding='latin1')
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...

# %%
pwd
# Out:
# 'C:\\Users\\lenovo'

# %%
pd.read_csv("Fortune500.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 pd.read_csv("Fortune500.csv")
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
# ...

# %%
pd.read_csv("Attendance Sheet 2022-2023_Masked.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 pd.read_csv("Attendance Sheet 2022-2023_Masked.csv")
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...

# %%
pd.read_csv("Downloads//archive//Fortune500.csv", encoding = "latin1")
# Out:
#      Rank        Company Name Number of Employees  Previous Rank   Revenues  \
# 0       1             Walmart           23,00,000            1.0  $4,85,873
# 1       2  Berkshire Hathaway            3,67,700            4.0  $2,23,604
# 2       3               Apple            1,16,000            3.0  $2,15,639
# 3       4         Exxon Mobil              72,700            2.0  $2,05,004
# 4       5            McKesson              68,000            5.0  $1,92,487
# ..    ...                 ...                 ...            ...        ...
# 495   496       Michaels Cos.              31,000          517.0     $5,197
# 496   497       Toll Brothers               4,200          576.0     $5,170
# 497   498               Yahoo               8,500          513.0     $5,169
# 498   499       Vistra Energy               4,431            NaN     $5,164
# 499   500      ABM Industries            1,10,000          485.0     $5,145
#
# ...

# %%
pd.read_csv("Downloads//archive (1)//Fortune_1000.csv")
# Out:
#                 company  rank  rank_change   revenue   profit  \
# 0               Walmart     1          0.0  572754.0  13673.0
# 1                Amazon     2          0.0  469822.0  33364.0
# 2                 Apple     3          0.0  365817.0  94680.0
# 3            CVS Health     4          0.0  292111.0   7910.0
# 4    UnitedHealth Group     5          0.0  287597.0  17285.0
# ..                  ...   ...          ...       ...      ...
# 995       Vizio Holding   996          0.0    2124.0    -39.4
# 996   1-800-Flowers.com   997          0.0    2122.2    118.7
# 997               Cowen   998          0.0    2112.8    295.6
# 998             Ashland   999          0.0    2111.0    220.0
# 999            DocuSign  1000          0.0    2107.2    -70.0
#
#      num. of employees       sector           city state newcomer ceo_founder  \
# 0            2300000.0    Retailing    Bentonville    AR       no          no
# ...

# %%
company = pd.read_csv("Downloads//archive (1)//Fortune_1000.csv")

# %%
company.head(2)
# Out:
#    company  rank  rank_change   revenue   profit  num. of employees  \
# 0  Walmart     1          0.0  572754.0  13673.0          2300000.0
# 1   Amazon     2          0.0  469822.0  33364.0          1608000.0
#
#       sector         city state newcomer ceo_founder ceo_woman profitable  \
# 0  Retailing  Bentonville    AR       no          no        no        yes
# 1  Retailing      Seattle    WA       no          no        no        yes
#
#   prev_rank                  CEO                        Website Ticker  \
# 0       1.0  C. Douglas McMillon  https://www.stock.walmart.com    WMT
# 1       2.0      Andrew R. Jassy                 www.amazon.com   AMZN
#
#   Market Cap
# 0     352037
# 1    1202717

# %%
company.groupby("sector")

# %%
sectors = company.groupby("sector")

# %%
sectors

# %%
len(company)
# Out:
# 1000

# %%
len(sectors)
# Out:
# 21

# %%
sectors.size()
# Out:
# sector
# Aerospace & Defense               17
# Apparel                           16
# Business Services                 52
# Chemicals                         29
# Energy                           100
# Engineering & Construction        32
# Financials                       166
# Food & Drug Stores                 9
# Food, Beverages & Tobacco         34
# Health Care                       77
# Hotels, Restaurants & Leisure     28
# Household Products                23
# Industrials                       50
# Materials                         46
# Media                             28
# Motor Vehicles & Parts            20
# Retailing                         77
# Technology                       121
# Telecommunications                 9
# Transportation                    35
# Wholesalers                       31
# dtype: int64

# %%
sectors.size().sort_values(ascending = False)
# Out:
# sector
# Financials                       166
# Technology                       121
# Energy                           100
# Health Care                       77
# Retailing                         77
# Business Services                 52
# Industrials                       50
# Materials                         46
# Transportation                    35
# Food, Beverages & Tobacco         34
# Engineering & Construction        32
# Wholesalers                       31
# Chemicals                         29
# Media                             28
# Hotels, Restaurants & Leisure     28
# Household Products                23
# Motor Vehicles & Parts            20
# Aerospace & Defense               17
# Apparel                           16
# Telecommunications                 9
# Food & Drug Stores                 9
# dtype: int64

# %%
sectors.first()
# Out:
#                                                 company  rank  rank_change  \
# sector
# Aerospace & Defense                     Lockheed Martin    55         -6.0
# Apparel                                            Nike    83          2.0
# Business Services                                PayPal   143         -9.0
# Chemicals                                           Dow    64         18.0
# Energy                                      Exxon Mobil     6          4.0
# Engineering & Construction                  D.R. Horton   124         24.0
# Financials                           Berkshire Hathaway     7         -1.0
# Food & Drug Stores             Walgreens Boots Alliance    18         -2.0
# Food, Beverages & Tobacco        Archer Daniels Midland    38         13.0
# Health Care                                  CVS Health     4          0.0
# Hotels, Restaurants & Leisure                 Starbucks   120          5.0
# ...

# %%
sectors.last()
# Out:
#                                                 company  rank  rank_change  \
# sector
# Aerospace & Defense                    BWX Technologies   995          0.0
# Apparel                                           Crocs   954          0.0
# Business Services                                Harsco   991          0.0
# Chemicals                                       Ashland   999          0.0
# Energy                                   Genesis Energy   994          0.0
# Engineering & Construction             Beazer Homes USA   992          0.0
# Financials                                        Cowen   998          0.0
# Food & Drug Stores               Grocery Outlet Holding   816          0.0
# Food, Beverages & Tobacco                  Brown-Forman   759          0.0
# Health Care                                      Chemed   993          0.0
# Hotels, Restaurants & Leisure         Acushnet Holdings   990          0.0
# ...

# %%
sectors.groups
# Out:
# {'Aerospace & Defense': [54, 57, 59, 93, 100, 205, 301, 369, 611, 623, 639, 697, 732, 861, 971, 980, 994], 'Apparel': [82, 379, 384, 457, 505, 539, 540, 545, 657, 753, 812, 884, 917, 922, 933, 953], 'Business Services': [142, 146, 166, 189, 202, 207, 226, 241, 254, 267, 313, 328, 352, 362, 406, 416, 469, 493, 509, 511, 573, 598, 607, 610, 616, 617, 648, 651, 662, 669, 674, 676, 677, 685, 714, 739, 803, 808, 828, 830, 852, 867, 881, 901, 915, 929, 965, 972, 974, 984, 986, 990], 'Chemicals': [63, 101, 174, 212, 217, 292, 304, 319, 321, 348, 349, 392, 405, 409, 491, 501, 517, 602, 615, 621, 765, 779, 786, 836, 940, 946, 948, 949, 998], 'Energy': [5, 15, 18, 28, 29, 53, 76, 87, 88, 98, 110, 129, 132, 134, 144, 152, 156, 167, 169, 192, 196, 214, 215, 218, 222, 223, 232, 238, 240, 242, 247, 256, 275, 277, 287, 307, 308, 314, 320, 332, 342, 343, 345, 346, 357, 361, 399, 413, 415, 430, 446, 450, 454, 468, 478, 484, 485, 499, 534, 543, 546, 557, 565, 568, 580, 618, 633, 638, 643, 701, 713, 71
# ...

# %%
company.iloc[69]
# Out:
# company                          Sysco
# rank                                70
# rank_change                      -10.0
# revenue                        51297.8
# profit                           524.2
# num. of employees              57710.0
# sector                     Wholesalers
# city                           Houston
# state                               TX
# newcomer                            no
# ceo_founder                         no
# ceo_woman                           no
# profitable                         yes
# prev_rank                         60.0
# CEO                  Kevin P. Hourican
# Website                  www.sysco.com
# Ticker                             SYY
# Market Cap                       44508
# Name: 69, dtype: object

# %%
company.loc[]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 company.loc["Media"]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1431, in _LocIndexer._getitem_axis(self, key, axis)
#    1429 # fall thru to straight lookup
#    1430 self._validate_key(key, axis)
# -> 1431 return self._get_label(key, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1381, in _LocIndexer._get_label(self, label, axis)
#    1379 def _get_label(self, label, axis: AxisInt):
# ...

# %%
company.head(2)
# Out:
#    company  rank  rank_change   revenue   profit  num. of employees  \
# 0  Walmart     1          0.0  572754.0  13673.0          2300000.0
# 1   Amazon     2          0.0  469822.0  33364.0          1608000.0
#
#       sector         city state newcomer ceo_founder ceo_woman profitable  \
# 0  Retailing  Bentonville    AR       no          no        no        yes
# 1  Retailing      Seattle    WA       no          no        no        yes
#
#   prev_rank                  CEO                        Website Ticker  \
# 0       1.0  C. Douglas McMillon  https://www.stock.walmart.com    WMT
# 1       2.0      Andrew R. Jassy                 www.amazon.com   AMZN
#
#   Market Cap
# 0     352037
# 1    1202717

# %%
company.loc[0]
# Out:
# company                                    Walmart
# rank                                             1
# rank_change                                    0.0
# revenue                                   572754.0
# profit                                     13673.0
# num. of employees                        2300000.0
# sector                                   Retailing
# city                                   Bentonville
# state                                           AR
# newcomer                                        no
# ceo_founder                                     no
# ceo_woman                                       no
# profitable                                     yes
# prev_rank                                      1.0
# CEO                            C. Douglas McMillon
# Website              https://www.stock.walmart.com
# Ticker                                         WMT
# Market Cap                                  352037
# Name: 0, dtype: object

# %%
table_index = company["company"]

# %%
company.index = table_index

# %%
company
# Out:
#                                company  rank  rank_change   revenue   profit  \
# company
# Walmart                        Walmart     1          0.0  572754.0  13673.0
# Amazon                          Amazon     2          0.0  469822.0  33364.0
# Apple                            Apple     3          0.0  365817.0  94680.0
# CVS Health                  CVS Health     4          0.0  292111.0   7910.0
# UnitedHealth Group  UnitedHealth Group     5          0.0  287597.0  17285.0
# ...                                ...   ...          ...       ...      ...
# Vizio Holding            Vizio Holding   996          0.0    2124.0    -39.4
# 1-800-Flowers.com    1-800-Flowers.com   997          0.0    2122.2    118.7
# Cowen                            Cowen   998          0.0    2112.8    295.6
# Ashland                        Ashland   999          0.0    2111.0    220.0
# DocuSign                      DocuSign  1000          0.0    2107.2    -70.0
#
# ...

# %%
company.loc["Walmart"]
# Out:
# company                                    Walmart
# rank                                             1
# rank_change                                    0.0
# revenue                                   572754.0
# profit                                     13673.0
# num. of employees                        2300000.0
# sector                                   Retailing
# city                                   Bentonville
# state                                           AR
# newcomer                                        no
# ceo_founder                                     no
# ceo_woman                                       no
# profitable                                     yes
# prev_rank                                      1.0
# CEO                            C. Douglas McMillon
# Website              https://www.stock.walmart.com
# Ticker                                         WMT
# Market Cap                                  352037
# Name: Walmart, dtype: object

# %%
company.reset_index(drop = True, inplace =True)

# %%
company
# Out:
#                 company  rank  rank_change   revenue   profit  \
# 0               Walmart     1          0.0  572754.0  13673.0
# 1                Amazon     2          0.0  469822.0  33364.0
# 2                 Apple     3          0.0  365817.0  94680.0
# 3            CVS Health     4          0.0  292111.0   7910.0
# 4    UnitedHealth Group     5          0.0  287597.0  17285.0
# ..                  ...   ...          ...       ...      ...
# 995       Vizio Holding   996          0.0    2124.0    -39.4
# 996   1-800-Flowers.com   997          0.0    2122.2    118.7
# 997               Cowen   998          0.0    2112.8    295.6
# 998             Ashland   999          0.0    2111.0    220.0
# 999            DocuSign  1000          0.0    2107.2    -70.0
#
#      num. of employees       sector           city state newcomer ceo_founder  \
# 0            2300000.0    Retailing    Bentonville    AR       no          no
# ...

# %%
sectors.get_group('Energy')
# Out:
#                            company  rank  rank_change   revenue   profit  \
# 5                      Exxon Mobil     6          4.0  285640.0  23040.0
# 15                         Chevron    16         11.0  162465.0  15625.0
# 18              Marathon Petroleum    19         13.0  141032.0   9738.0
# 28                     Phillips 66    29         19.0  114852.0   1317.0
# 29                   Valero Energy    30         23.0  108332.0    930.0
# ..                             ...   ...          ...       ...      ...
# 964  Alpha Metallurgical Resources   965          0.0    2258.6    288.8
# 973                          Spire   974          0.0    2235.5    271.7
# 979                 Arch Resources   980          0.0    2208.0    337.6
# 988           New Jersey Resources   989          0.0    2156.6    117.9
# 993                 Genesis Energy   994          0.0    2125.5   -165.1
#
#      num. of employees  sector         city state newcomer ceo_founder  \
# ...

# %%
sectors.get_group('Energy').shape[0]
# Out:
# 100

# %%
sectors.sum()
# Out:
#                                                                          company  \
# sector
# Aerospace & Defense            Lockheed MartinRaytheon TechnologiesBoeingGene...
# Apparel                        NikeVF Corp.PVHHanesbrandsSkechers U.S.A.Levi ...
# Business Services              PayPalVisaManpowerGroupMastercardWaste Managem...
# Chemicals                      Dow3MSherwin-WilliamsDuPontPPG IndustriesEcola...
# Energy                         Exxon MobilChevronMarathon PetroleumPhillips 6...
# Engineering & Construction     D.R. HortonLennarFluorAECOMJacobs Engineering ...
# Financials                     Berkshire HathawayJPMorgan ChaseFannie MaeBank...
# Food & Drug Stores             Walgreens Boots AllianceKrogerAlbertsonsPublix...
# Food, Beverages & Tobacco      Archer Daniels MidlandPepsiCoTyson FoodsCoca-C...
# Health Care                    CVS HealthUnitedHealth GroupMcKessonAmerisourc...
# ...
